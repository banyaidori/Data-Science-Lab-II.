# %% [markdown]
# # Import

# %%
from BeeDataClass import BeeData
from GAClass import GeneticAlgorithm
import Constants

# %% [markdown]
# # Visualization examples

# %%
data_0502 = BeeData(Constants.FOLDER[0], Constants.SWARMING, pickle_file_name = '2023-01-23-19-47-47.pkl', read_from_pickle = True, convert_pcm_wav=False)
df_0502 = data_0502.get_dataframe()
data_0502.visualize_audio(df_0502.iloc[30]['filename'])

# %%
data_0524 = BeeData(Constants.FOLDER[1], Constants.SWARMING, pickle_file_name = '2023-01-23-19-09-24.pkl', read_from_pickle = True, convert_pcm_wav=False)
df_0524 = data_0524.get_dataframe()
data_0524.visualize_audio(df_0524.iloc[30]['filename'])
